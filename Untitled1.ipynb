# %%
from plotly.offline import init_notebook_mode, iplot
import plotly.graph_objs as go

# Inicjalizacja trybu offline
init_notebook_mode(connected=True)
import plotly.offline as pyo
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import pandas as pd

# %%
ca = pd.read_csv('ca_c_f_d.csv')
ca.head()
# Out:
#          Data  Otwarcie  Najwyzszy  Najnizszy  Zamkniecie
# 0  2015-01-02    6309.0     6309.0     6309.0      6309.0
# 1  2015-01-05    6216.0     6216.0     6216.0      6216.0
# 2  2015-01-06    6191.0     6191.0     6191.0      6191.0
# 3  2015-01-07    6170.0     6170.0     6170.0      6170.0
# 4  2015-01-08    6230.5     6230.5     6230.5      6230.5

# %%
kgh = pd.read_csv('kgh_d.csv')
kgh.head()
# Out:
#          Data  Otwarcie  Najwyzszy  Najnizszy  Zamkniecie  Wolumen
# 0  2015-01-02    102.45     102.83     101.97      102.40   309987
# 1  2015-01-05    102.16     102.88      99.91      100.09   479228
# 2  2015-01-07    100.53     105.45      99.67      104.89   966372
# 3  2015-01-08    105.35     107.15     105.35      107.11   711805
# 4  2015-01-09    107.15     107.15     103.87      104.33   563221

# %%
kgh.set_index('Data')['Zamkniecie'].iplot(kind='line', color='blue', title='KHGM')
ca.set_index('Data')['Zamkniecie'].iplot(kind='line', color='red',title='Miedź')

# %%
fig = go.Figure(data=[go.Table(
    header=dict(
        values=["Data", "KGH", "Miedź"],
        fill_color='paleturquoise',
        align='left'
    ),
    cells=dict(
        values=[kgh.Data, kgh.Zamkniecie, ca.Zamkniecie],
        fill_color='lavender',
        align='left'
    )
)])

fig.show()
